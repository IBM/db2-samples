# %%
import pandas as pd
import csv

df = pd.read_csv('shoes-vectors.csv', quoting=csv.QUOTE_NONNUMERIC)

# %%
df.head()
# Out:
#         SKU           PRODUCT_NAME      BRAND  CLASS     TYPE   MATERIAL  \
# 0  ZEN-5999      Zentrax X Walking    Zentrax  Women  Walking  Synthetic
# 1  RUN-4723  RunXpress Max Walking  RunXpress  Women  Walking  Synthetic
# 2  ZEN-8968    Zentrax Pro Running    Zentrax    Men  Running  Synthetic
# 3  RUN-7569    RunXpress X Walking  RunXpress    Men  Walking  Synthetic
# 4  RUN-1083    RunXpress X Walking  RunXpress  Women  Walking  Synthetic
#
#    COLOR WEATHER_RESISTANCE ARCH_SUPPORT  SIZE   PRICE  RATING  STORE_ID  \
# 0  White          Resistant         High   8.0  108.65     4.3       1.0
# 1  White         Waterproof         High   8.5  103.22     3.0      20.0
# 2  Black         Waterproof         High   7.5  100.25     3.7      13.0
# 3  Black         Waterproof         Flat   7.5   83.84     3.2       4.0
# 4  Black          Resistant         Flat  12.5  139.70     3.8       2.0
#
#       CITY                                          EMBEDDING
# 0   Ottawa  [0.037853196, 0.0047503645, -0.042236183, -0.0...
# 1   Ottawa  [0.035730753, 0.0032045494, -0.039743163, -0.0...
# 2  Toronto  [0.023130681, 0.0013610307, -0.042692233, -0.0...
# 3   Ottawa  [0.02354851, 0.004738677, -0.03867846, -0.0353...
# 4  Toronto  [0.02477072, 0.0077166175, -0.041874062, -0.02...

# %%
def format_embedding(embedding_list):
    return f"VECTOR({embedding_list}, 1024, FLOAT32)"

df['EMBEDDING'] = df['EMBEDDING'].apply(format_embedding)

# %%
df.head()
# Out:
#         SKU           PRODUCT_NAME      BRAND  CLASS     TYPE   MATERIAL  \
# 0  ZEN-5999      Zentrax X Walking    Zentrax  Women  Walking  Synthetic
# 1  RUN-4723  RunXpress Max Walking  RunXpress  Women  Walking  Synthetic
# 2  ZEN-8968    Zentrax Pro Running    Zentrax    Men  Running  Synthetic
# 3  RUN-7569    RunXpress X Walking  RunXpress    Men  Walking  Synthetic
# 4  RUN-1083    RunXpress X Walking  RunXpress  Women  Walking  Synthetic
#
#    COLOR WEATHER_RESISTANCE ARCH_SUPPORT  SIZE   PRICE  RATING  STORE_ID  \
# 0  White          Resistant         High   8.0  108.65     4.3       1.0
# 1  White         Waterproof         High   8.5  103.22     3.0      20.0
# 2  Black         Waterproof         High   7.5  100.25     3.7      13.0
# 3  Black         Waterproof         Flat   7.5   83.84     3.2       4.0
# 4  Black          Resistant         Flat  12.5  139.70     3.8       2.0
#
#       CITY                                          EMBEDDING
# 0   Ottawa  VECTOR([0.037853196, 0.0047503645, -0.04223618...
# 1   Ottawa  VECTOR([0.035730753, 0.0032045494, -0.03974316...
# 2  Toronto  VECTOR([0.023130681, 0.0013610307, -0.04269223...
# 3   Ottawa  VECTOR([0.02354851, 0.004738677, -0.03867846, ...
# 4  Toronto  VECTOR([0.02477072, 0.0077166175, -0.041874062...

# %%
df.shape
# Out:
# (500, 15)

# %%
df.columns
# Out:
# Index(['SKU', 'PRODUCT_NAME', 'BRAND', 'CLASS', 'TYPE', 'MATERIAL', 'COLOR',
#        'WEATHER_RESISTANCE', 'ARCH_SUPPORT', 'SIZE', 'PRICE', 'RATING',
#        'STORE_ID', 'CITY', 'EMBEDDING'],
#       dtype='object')

# %%
import pandas as pd
import csv

# Assuming df_shoes is your original DataFrame
cols_data = [
    'SKU', 'PRODUCT_NAME', 'BRAND', 'CLASS', 'TYPE', 'MATERIAL', 'COLOR',
    'WEATHER_RESISTANCE', 'ARCH_SUPPORT', 'SIZE', 'PRICE', 'RATING',
    'STORE_ID', 'CITY'
]

cols_vectors = ['SKU', 'EMBEDDING']

# Split into two DataFrames
df_data = df[cols_data]
df_vectors = df[cols_vectors]

# Save to CSVs
df_data.to_csv('shoes.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)
df_vectors.to_csv('vectors.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)
